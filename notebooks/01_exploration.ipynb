# %% [markdown]
# # Toxicity + LD50 Exploration
# This notebook is a starting point for EDA, feature checks, and SHAP analysis.

# %%
import pandas as pd
from pathlib import Path

data_path = Path('data/train.csv')
df = pd.read_csv(data_path)
df.head()

# %%
df.describe(include='all').T.head(20)
